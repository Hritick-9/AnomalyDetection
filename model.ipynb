# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import IsolationForest
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt


np.random.seed(42)

# Number of samples
num_normal_samples = 50000  
num_anomalous_samples = 2500  


normal_heart_rate = np.random.normal(loc=75, scale=5, size=num_normal_samples).astype(int)
normal_spo2 = np.random.normal(loc=98, scale=1, size=num_normal_samples)  


normal_heart_rate = np.clip(normal_heart_rate, 60, 100) 
normal_spo2 = np.clip(normal_spo2, 95, 100)


anomalous_heart_rate = np.random.normal(loc=130, scale=10, size=num_anomalous_samples).astype(int)  
anomalous_spo2 = np.random.normal(loc=80, scale=5, size=num_anomalous_samples)  

# Clip to ensure values are outside healthy ranges
anomalous_heart_rate = np.clip(anomalous_heart_rate, 110, 150)  
anomalous_spo2 = np.clip(anomalous_spo2, 70, 90)  


heart_rate = np.concatenate([normal_heart_rate, anomalous_heart_rate])
spo2 = np.concatenate([normal_spo2, anomalous_spo2])
labels = np.concatenate([np.ones(num_normal_samples), -np.ones(num_anomalous_samples)]) 


df = pd.DataFrame({
    'Heart Rate (BPM)': heart_rate,
    'SpO2': spo2,
    'Label': labels
})


df = df.sample(frac=1, random_state=42).reset_index(drop=True)





train_df = df[df['Label'] == 1]  
test_df = df  


X_train = train_df[['Heart Rate (BPM)', 'SpO2']]  
X_test = test_df[['Heart Rate (BPM)', 'SpO2']] 
y_test = test_df['Label'] 


from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


clf = IsolationForest(n_estimators=200, max_samples=256, contamination=0.01, random_state=42)
clf.fit(X_train_scaled) 


test_df['Predicted Label'] = clf.predict(X_test_scaled) 
test_df['Anomaly Score'] = clf.decision_function(X_test_scaled)
# Out:
# Fontconfig warning: ignoring UTF-8: not a valid region tag
# Matplotlib is building the font cache; this may take a moment.

# %%
print("\nClassification Report:")
print(classification_report(y_test, test_df['Predicted Label'], target_names=["Normal", "Anomaly"]))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.83      1.00      0.91      2500
#      Anomaly       1.00      0.99      0.99     50000
#
#     accuracy                           0.99     52500
#    macro avg       0.92      0.99      0.95     52500
# weighted avg       0.99      0.99      0.99     52500

# %%
from flask import Flask, request, jsonify
import numpy as np


app = Flask(__name__)


@app.route('/predict', methods=['POST'])
def predict():
    try:
    
        data = request.json
        heart_rate = data.get("heart_rate")
        spo2 = data.get("spo2")

   
        if heart_rate is None or spo2 is None:
            return jsonify({"error": "Missing heart_rate or spo2 value"}), 400

      
        input_data = np.array([[heart_rate, spo2]])
        input_scaled = scaler.transform(input_data)  

       
        prediction = clf.predict(input_scaled)[0]
        anomaly_score = clf.decision_function(input_scaled)[0]

       
        result = "Normal" if prediction == 1 else "Anomalous"

        return jsonify({
            "heart_rate": heart_rate,
            "spo2": spo2,
            "prediction": result,
            "anomaly_score": anomaly_score
        })

    except Exception as e:
        return jsonify({"error": str(e)}), 500



if __name__ == '__main__':
   app.run(port=5001)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5001
# Press CTRL+C to quit
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:10:44] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:10:47] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:10:50] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:10:53] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:10:56] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:10:59] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:11:02] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:11:05] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:11:08] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:11:11] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:11:14] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:11:17] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:11:20] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:11:23] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:11:26] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:11:29] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:12:06] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:12:09] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:12:12] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:12:15] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:12:18] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:12:21] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:12:31] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:12:34] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:12:37] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:12:40] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:12:43] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:12:46] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:12:49] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:12:52] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:12:55] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:12:58] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:13:01] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:13:04] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:13:07] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:13:10] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:13:13] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:13:16] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:13:19] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:13:29] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:13:32] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:13:35] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:13:38] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:13:41] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:13:44] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:13:47] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:13:50] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:13:57] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:00] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:03] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:06] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:09] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:12] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:15] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:18] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:21] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:24] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:27] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:30] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:33] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:36] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:39] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:42] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:45] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:48] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:51] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:54] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:14:57] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:00] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:03] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:06] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:09] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:12] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:15] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:18] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:21] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:24] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:27] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:30] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:33] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:36] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:39] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:42] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:45] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:48] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:51] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:54] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:15:57] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:00] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:03] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:06] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:09] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:12] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:15] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:18] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:21] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:24] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:27] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:30] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:33] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:36] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:39] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:42] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:45] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:48] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:51] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:16:52] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:17:26] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:17:29] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:17:32] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:17:35] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:17:38] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:17:41] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:17:44] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:17:47] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:17:50] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:17:53] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:17:56] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:17:59] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:02] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:05] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:08] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:11] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:14] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:17] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:20] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:23] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:26] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:29] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:29] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:32] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:32] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:35] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:35] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:38] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:38] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:41] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:41] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:44] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:44] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:47] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:47] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:50] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:50] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:53] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:53] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:56] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:56] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:59] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:18:59] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:19:02] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:19:02] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:19:05] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:19:05] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:19:08] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:19:08] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:19:11] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:19:11] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:19:14] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:19:14] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:19:17] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:19:17] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:19:20] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:19:20] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:19:23] "POST /predict HTTP/1.1" 200 -
# /Users/hritick/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [02/Feb/2025 12:19:23] "POST /predict HTTP/1.1" 200 -

# %%
# Out:
#   Cell In[15], line 1
#     ngrok http 5001
#           ^
# SyntaxError: invalid syntax
